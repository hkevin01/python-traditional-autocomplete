# %% [markdown]
# # Jupyter Notebook IntelliSense Test
# ## Testing Traditional Autocomplete WITHOUT Copilot
#
# **Goal**: Verify IntelliSense works but Copilot/AI is disabled
#
# ### Visual Indicators:
# - ✅ **IntelliSense ON**: Dropdown suggestions appear when typing
# - ✅ **Hover works**: Hover over code to see docstrings
# - ✅ **Tab completion**: Press Tab to complete suggestions
# - ❌ **Copilot OFF**: NO gray ghost text appears
# - ❌ **No AI**: NO multi-line code generation

# %% [markdown]
# ## Test 1: Import Autocomplete
# Type `import ` and press Tab or Ctrl+Space to see module suggestions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Test 2: NumPy Autocomplete

# %%
# Type 'np.' and see suggestions
array_data = np.array([1, 2, 3, 4, 5])
print(f"Mean: {array_data.mean()}")

# %% [markdown]
# ## Test 3: Pandas DataFrame

# %%
df = pd.DataFrame({
    'name': ['Alice', 'Bob'],
    'age': [25, 30]
})
display(df)

# %% [markdown]
# ## Results
# If dropdown menus appear (no ghost text): ✅ SUCCESS!
